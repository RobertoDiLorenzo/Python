# %% [markdown]
# ## Newton Method
#
# $x_n = x_0 + \frac{f(x_i)}{f'(x_i)}$

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x):
    return x**2 - 2
def f_prime(x,y, dx):
    int i = 0;
    y_prime = (y[i+1]+dx - y[i]) / dx 
    return y_prime

def plot_convergence(f, f_prime, x0, tolerance, max_iterations):
    x_values = [x0]
    y_values = [f(x0)]
    x = x0
    for i in range(max_iterations):
        x_new = x - f(x) / f_prime(x)
        x_values.append(x_new)
        y_values.append(f(x_new))
        if abs(x_new - x) < tolerance:
            break
        x = x_new
    
    plt.plot(x_values, y_values, marker='o')
    plt.xlabel('Iteration')
    plt.ylabel('f(x)')
    plt.title('Convergence of Newton Method')
    plt.show()
    
# Utilizzo della funzione per tracciare l'animazione della convergenza del punto
x0 = 2  # Valore iniziale
tolerance = 1e-6  # Tolleranza
max_iterations = 20  # Numero massimo di iterazioni
plot_convergence(f, f_prime, x0, tolerance, max_iterations)

def newton_method(f, f_prime, x0, tolerance, max_iterations):
    x = x0
    for i in range(max_iterations):
        x_new = x - f(x) / f_prime(x)
        if abs(x_new - x) < tolerance:
            return x_new, i
        x = x_new
    return None, max_iterations

print(f"The estimation is: {estimate}")

# %%
dx = 1
x_values = np.arange(0, 4, dx)
#print(x_values)
y = x_values**2 -2
#print(y)

def f_prime(x, y, dx):
    i = 0
    y_prime = np.zeros_like(y)       # define an empity array with same shape of y
    #print(len(x))      
    
    for i in range(i, len(x)-1):
        dx = x[i+1] - x[i]
        print(dx) 
        y_prime[i+1] = ( (y[i+1]+dx) - y[i]) / dx
        #print(y_prime)
    return y_prime
    
y_prime = f_prime(x_values, y, dx)
#print(len(y_prime))
#plt.plot(x_values, y)
#plt.plot(x_values, y_prime)

plt.figure()
plt.subplot(2, 1, 1)
plt.plot(x_values, y, label='f(x) = x^2 - 2')
plt.legend()
plt.subplot(2, 1, 2)
plt.plot(x_values, y_prime, label="f'(x)=2*x")
plt.legend()
#plt.show()
# Out:
# 1
# 1
# 1

# %%
dx = 1
xdata = np.arange(-4, 5, dx)
#print(xdata)
print('length of xdata:', len(xdata))
y = xdata**3
#print(y)

def f_prime(x, y):
    i = 0
    dxdata = x[0:len(x)]
    print('length of dxdata:', len(dxdata))
    y_prime = np.zeros_like(y)  # define an empity array with same shape of y
    for i in range(i, len(x)-1):
        dx = np.abs(x[i+1]) - np.abs(x[i])
        f_plus_dx = (y[i+1] + dx)
        f_vals = y[i]
        y_prime[i] = ( f_plus_dx - f_vals) / dx
        #y_prime[i] = ( (y[i+1] + dx) - y[i]) / dx
        #print(y_prime)
    return dxdata, y_prime
    
dxdata, y_prime = f_prime(xdata, y)

plt.figure()
plt.subplot(2, 1, 1)
plt.plot(dxdata, y, label='f(x) = x^3 - 2')
plt.legend()
plt.subplot(2, 1, 2)
plt.plot(dxdata, y_prime, label="f'(x)=3*x^2")
plt.legend()
#plt.show()
# Out:
# length of xdata: 9
# length of dxdata: 9

# %%
x0 = 2  # Valore iniziale
tolerance = 1  # Tolleranza
max_iterations = 20  # Numero massimo di iterazioni

def newton(xdata, y, x0, tolerance, max_iterations):
    """newton method to find a yero of a function.
    x0 = initial guess...
    And so on... 
    """
    i = 0
    x = x0
    for i in range(max_iterations):
        x_new = x - y[i] / f_prime(xdata, y)
        if abs(x_new - x) < tolerance:
            return x_new, i
        x = x_new
    return x #, max_iterations
    
x, max_iterations = newton(xdata, y, x0, tolerance, max_iterations)
print(f"The estimation is: {x}")
# Out:
# length of dxdata: 9
# C:\Users\rober\AppData\Local\Temp\ipykernel_19140\2260040600.py:13: RuntimeWarning: divide by zero encountered in divide
#   x_new = x - y[i] / f_prime(xdata, y)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[99], line 19
#      16         x = x_new
#      17     return x #, max_iterations
# ---> 19 x, max_iterations = newton(xdata, y, x0, tolerance, max_iterations)
#      20 print(f"The estimation is: {x}")
#
# Cell In[99], line 14, in newton(xdata, y, x0, tolerance, max_iterations)
#      12 for i in range(max_iterations):
#      13     x_new = x - y[i] / f_prime(xdata, y)
# ---> 14     if abs(x_new - x) < tolerance:
#      15         return x_new, i
#      16     x = x_new
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
